# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
a = 349
a += 10 - 360*(a+10>360)
a
60+180 - 90
# Out:
# 150

# %%
df = pd.read_csv ('data/newLogs/LOG3.csv', names=["time", "type","tag","text"])
mdf = pd.read_csv ('data/mpuLogs/LOG5.csv', names=["time", "type","tag","text"])

# %% [markdown]
# ### Design the State Variables
#
# For our robot we will maintain the position and orientation:
#
# $$\mathbf x = \begin{bmatrix}x & \dot x &  \ddot{x} & y & \dot y &  \ddot{y} \end{bmatrix}^\mathsf{T}$$
#
# I could include velocities into this model, but as you will see the math will already be quite challenging.
#
# The control input $\mathbf{u}$ is the commanded velocity and steering angle
#
# $$\mathbf{u} = \begin{bmatrix}v & \alpha\end{bmatrix}^\mathsf{T}$$

# %%
mpudf = pd.DataFrame(data=[np.asarray(el.split(), dtype=np.float64) for el in mdf.query("tag == 'mpu9250' and type == 4").text],
                    index = mdf.query("tag == 'mpu9250' and type == 4").time/1000,
                    columns=["heading", "pitch", "roll"])
#mpudf['heading'] += 90 - 360*(mpudf['heading']+90>360)
px.line(mpudf)

# %%
neo6mdf = pd.DataFrame(data=[(el["text"]+" "+ str(el['time']/1000)).split() for i,el in df.query("tag == 'neo6m' and type == 5").iterrows()],
                    columns=["lat", "lon", "cog","speed","variation","valid","time"],dtype=float)
neo6mdf['lat'] = neo6mdf['lat'].astype(float)
neo6mdf['lon'] = neo6mdf['lon'].astype(float)
fig = px.line_mapbox(neo6mdf, lat="lat", lon="lon",hover_data={"time","lat","lon","speed","cog"},text="time", zoom=3, height=600)     
fig.update_layout(mapbox_style="stamen-terrain", mapbox_zoom=17, mapbox_center_lat = neo6mdf.lat[0],mapbox_center_lon=neo6mdf.lon[0],
    margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
earthRate =  0.000072921
earthRadius =  6378145.0
earthRadiusInv =   1.5678540e-7
latRef = np.deg2rad(neo6mdf.lat[0])
lonRef = np.deg2rad(neo6mdf.lon[0])
altRef = 500

def lla2ned(lat, lon, alt=0):
    lat, lon = np.deg2rad(lat), np.deg2rad(lon) 
    xN = earthRadius * (lat - latRef)
    yE = earthRadius * np.cos(latRef) * (lon - lonRef)
    zD = -(alt - altRef)
    return xN,yE,zD
def ned2lla(xN,yE,zD=0):
    lat = latRef + xN * earthRadiusInv
    lon = lonRef + yE * earthRadiusInv / np.cos(latRef)
    alt = altRef - zD
    return np.rad2deg(lat),np.rad2deg(lon),alt
def vel2ned(speed,cog,velD=0):
    cog = np.deg2rad(cog)
    vx = speed*np.cos(cog)
    vy = speed*np.sin(cog)
    vz = velD
    return vx,vy,vz
def ned2vel(vx,vy):
    return (vx**2+vy**2)**0.5

def fx(x, dt):
    F = np.array([[1, dt, 0, 0 ],
                  [0, 1,  0, 0 ], 
                  [0, 0,  1, dt],
                  [0, 0,  0, 1]])
    return F @ x

def hx(x):
    return [x[0],x[2],x[1],x[3]]

# %%
from filterpy.kalman import UnscentedKalmanFilter as UKF
from filterpy.common import Q_discrete_white_noise
from filterpy.kalman import MerweScaledSigmaPoints
from filterpy.stats import mahalanobis

dt = 0.4

sigmas = MerweScaledSigmaPoints(4, alpha=.1, beta=2., kappa=1.)
ukf = UKF(dim_x=4, dim_z=4, fx=fx,
          hx=hx, dt=dt, points=sigmas,)
ukf.x = np.array([0., 0., 0., 0.])
ukf.R = np.diag([6**2, 6**2,6**2,6**2])
ukf.P = np.diag([50,20,50,20]) 
ukf.Q = Q_discrete_white_noise(dim=2, dt=dt, var=.2,block_size=2)

# %%
last_t = 0
latarr,lonarr,velarr = [],[],[]
for index, row in neo6mdf.iterrows():
    dt = row['time'] - last_t
    last_t = row['time']
    ukf.Q = Q_discrete_white_noise(dim=2, dt=dt, var=.2,block_size=2)
    ukf.predict(dt)
    #mesto cog ke se koristi heading 
    # [row['heading'] for index, row in mpudf.iterrows() if (index>last_t)][0]
    vx,vy,_=vel2ned(row['speed'],134 if row['cog'] == 0 else row['cog'])
    x,y,_ = lla2ned(row['lat'],row['lon'])
    GATE_LIMIT = 4.
    std = np.sqrt(ukf.P.diagonal())
    err = [x-ukf.x[0],y-ukf.x[2]]
    if err[0] > GATE_LIMIT * std[0] or err[1] > GATE_LIMIT * std[2]:
        print(f'discarding measurement, error is {err[0]/std[0]:.0f} std, {err[1]/std[2]:.0f} std time: {last_t}')
        lat,lon,_ = ned2lla(ukf.x[0],ukf.x[2])
        latarr.append(lat)
        lonarr.append(lon)
        velarr.append(ned2vel(ukf.x[1],ukf.x[3]))
        continue
    ukf.update([x,y,vx,vy])
    lat,lon,_ = ned2lla(ukf.x[0],ukf.x[2])
    latarr.append(lat)
    lonarr.append(lon)
    velarr.append(ned2vel(ukf.x[1],ukf.x[3]))
# Out:
# discarding measurement, error is 6 std, -3 std time: 19.044
# discarding measurement, error is 8 std, -3 std time: 19.282
# discarding measurement, error is 9 std, -3 std time: 19.576
# discarding measurement, error is 10 std, -3 std time: 19.81
# discarding measurement, error is 11 std, -3 std time: 20.054
# discarding measurement, error is 11 std, -3 std time: 20.292
# discarding measurement, error is 13 std, -3 std time: 20.526
# discarding measurement, error is 14 std, -2 std time: 20.688
# discarding measurement, error is 15 std, -3 std time: 21.036
# discarding measurement, error is 16 std, -3 std time: 21.266
# discarding measurement, error is 16 std, -3 std time: 21.384
# discarding measurement, error is 17 std, -3 std time: 21.674
# discarding measurement, error is 18 std, -3 std time: 22.044
# discarding measurement, error is 19 std, -3 std time: 22.156
# discarding measurement, error is 19 std, -4 std time: 22.516
# discarding measurement, error is 19 std, -4 std time: 22.812
# discarding measurement, error is 20 std, -4 std time: 23.042
# discarding measurement, error is 20 std, -4 std time: 23.28
# discarding measurement, error is 19 std, -4 std time: 23.518
# discarding measurement, error is 19 std, -4 std time: 23.758
# discarding measurement, error is 18 std, -4 std time: 23.996
# discarding measurement, error is 18 std, -4 std time: 24.286
# discarding measurement, error is 18 std, -4 std time: 24.524
# discarding measurement, error is 17 std, -4 std time: 24.758
# discarding measurement, error is 17 std, -4 std time: 24.996
# discarding measurement, error is 17 std, -4 std time: 25.12
# discarding measurement, error is 17 std, -4 std time: 25.478
# discarding measurement, error is 17 std, -4 std time: 25.8
# discarding measurement, error is 16 std, -4 std time: 25.914
# discarding measurement, error is 16 std, -4 std time: 26.152
# discarding measurement, error is 16 std, -4 std time: 26.518
# discarding measurement, error is 16 std, -4 std time: 26.634
# discarding measurement, error is 16 std, -4 std time: 27.066
# discarding measurement, error is 16 std, -4 std time: 27.304
# discarding measurement, error is 16 std, -4 std time: 27.542
# discarding measurement, error is 16 std, -4 std time: 27.78
# discarding measurement, error is 16 std, -4 std time: 28.072
# discarding measurement, error is 17 std, -4 std time: 28.306
# discarding measurement, error is 17 std, -5 std time: 28.544
# discarding measurement, error is 17 std, -5 std time: 28.782
# discarding measurement, error is 17 std, -5 std time: 29.076
# discarding measurement, error is 17 std, -5 std time: 29.31
# discarding measurement, error is 17 std, -5 std time: 29.544
# discarding measurement, error is 18 std, -5 std time: 29.658
# discarding measurement, error is 18 std, -5 std time: 30.014
# discarding measurement, error is 18 std, -5 std time: 30.254
# discarding measurement, error is 18 std, -5 std time: 30.368
# discarding measurement, error is 18 std, -5 std time: 30.63
# discarding measurement, error is 18 std, -5 std time: 31.064
# discarding measurement, error is 18 std, -5 std time: 31.182
# discarding measurement, error is 18 std, -5 std time: 31.546
# discarding measurement, error is 18 std, -5 std time: 31.78
# discarding measurement, error is 18 std, -5 std time: 32.012
# discarding measurement, error is 18 std, -6 std time: 32.302
# discarding measurement, error is 18 std, -6 std time: 32.536
# discarding measurement, error is 18 std, -6 std time: 32.768
# discarding measurement, error is 18 std, -6 std time: 32.998
# discarding measurement, error is 18 std, -6 std time: 33.292
# discarding measurement, error is 18 std, -6 std time: 33.518
# discarding measurement, error is 17 std, -6 std time: 33.74
# discarding measurement, error is 17 std, -6 std time: 33.964
# discarding measurement, error is 18 std, -6 std time: 34.072
# discarding measurement, error is 18 std, -7 std time: 34.496
# discarding measurement, error is 18 std, -7 std time: 34.758
# discarding measurement, error is 18 std, -7 std time: 34.866
# discarding measurement, error is 18 std, -7 std time: 35.082
# discarding measurement, error is 18 std, -7 std time: 35.432
# discarding measurement, error is 18 std, -7 std time: 35.542
# discarding measurement, error is 17 std, -7 std time: 35.892
# discarding measurement, error is 17 std, -7 std time: 36.172
# discarding measurement, error is 17 std, -7 std time: 36.392
# discarding measurement, error is 17 std, -7 std time: 36.614
# discarding measurement, error is 17 std, -8 std time: 36.84
# discarding measurement, error is 17 std, -8 std time: 37.12
# discarding measurement, error is 17 std, -8 std time: 37.342
# discarding measurement, error is 17 std, -8 std time: 37.566
# discarding measurement, error is 16 std, -8 std time: 37.862
# discarding measurement, error is 16 std, -8 std time: 38.1
# discarding measurement, error is 16 std, -8 std time: 38.332
# discarding measurement, error is 16 std, -8 std time: 38.49
# discarding measurement, error is 16 std, -8 std time: 38.848
# discarding measurement, error is 16 std, -8 std time: 39.088
# discarding measurement, error is 16 std, -8 std time: 39.2
# discarding measurement, error is 15 std, -8 std time: 39.674
# discarding measurement, error is 15 std, -9 std time: 39.79
# discarding measurement, error is 15 std, -9 std time: 40.228
# discarding measurement, error is 15 std, -9 std time: 40.468
# discarding measurement, error is 15 std, -9 std time: 40.702
# discarding measurement, error is 15 std, -9 std time: 40.992
# discarding measurement, error is 15 std, -9 std time: 41.23
# discarding measurement, error is 15 std, -9 std time: 41.52
# discarding measurement, error is 14 std, -9 std time: 41.758
# discarding measurement, error is 14 std, -9 std time: 42.052
# discarding measurement, error is 14 std, -9 std time: 42.29
# discarding measurement, error is 14 std, -9 std time: 42.532
# discarding measurement, error is 14 std, -9 std time: 42.77
# discarding measurement, error is 14 std, -9 std time: 42.93
# discarding measurement, error is 14 std, -9 std time: 43.294
# discarding measurement, error is 14 std, -9 std time: 43.534
# discarding measurement, error is 14 std, -10 std time: 43.696
# discarding measurement, error is 13 std, -10 std time: 43.986
# discarding measurement, error is 13 std, -10 std time: 44.102
# discarding measurement, error is 13 std, -10 std time: 44.466
# discarding measurement, error is 13 std, -10 std time: 44.738
# discarding measurement, error is 13 std, -10 std time: 44.976
# discarding measurement, error is 13 std, -10 std time: 45.272
# discarding measurement, error is 13 std, -10 std time: 45.51
# discarding measurement, error is 13 std, -10 std time: 45.744
# discarding measurement, error is 13 std, -10 std time: 46.044
# discarding measurement, error is 13 std, -10 std time: 46.28
# discarding measurement, error is 13 std, -10 std time: 46.522
# discarding measurement, error is 13 std, -10 std time: 46.758
# discarding measurement, error is 13 std, -10 std time: 47.054
# discarding measurement, error is 12 std, -10 std time: 47.29
# discarding measurement, error is 12 std, -10 std time: 47.406
# discarding measurement, error is 12 std, -10 std time: 47.774
# discarding measurement, error is 12 std, -10 std time: 48.066
# discarding measurement, error is 12 std, -10 std time: 48.184
# discarding measurement, error is 12 std, -11 std time: 48.552
# discarding measurement, error is 12 std, -11 std time: 48.668
# discarding measurement, error is 12 std, -11 std time: 49.03
# discarding measurement, error is 12 std, -11 std time: 49.27
# discarding measurement, error is 12 std, -11 std time: 49.506
# discarding measurement, error is 12 std, -11 std time: 49.834
# discarding measurement, error is 12 std, -11 std time: 50.074
# discarding measurement, error is 12 std, -11 std time: 50.31
# discarding measurement, error is 12 std, -11 std time: 50.552
# discarding measurement, error is 12 std, -11 std time: 50.792
# discarding measurement, error is 12 std, -11 std time: 51.086
# discarding measurement, error is 12 std, -11 std time: 51.316
# discarding measurement, error is 12 std, -11 std time: 51.554
# discarding measurement, error is 12 std, -11 std time: 51.794
# discarding measurement, error is 12 std, -12 std time: 51.91
# discarding measurement, error is 12 std, -12 std time: 52.344
# discarding measurement, error is 12 std, -12 std time: 52.584
# discarding measurement, error is 11 std, -12 std time: 52.702
# discarding measurement, error is 11 std, -12 std time: 53.064
# discarding measurement, error is 11 std, -12 std time: 53.178
# discarding measurement, error is 11 std, -12 std time: 53.552
# discarding measurement, error is 11 std, -12 std time: 53.84
# discarding measurement, error is 11 std, -12 std time: 54.074
# discarding measurement, error is 11 std, -12 std time: 54.238
# discarding measurement, error is 11 std, -12 std time: 54.47
# discarding measurement, error is 11 std, -12 std time: 54.8
# discarding measurement, error is 11 std, -12 std time: 55.04
# discarding measurement, error is 11 std, -12 std time: 55.28
# discarding measurement, error is 11 std, -12 std time: 55.514
# discarding measurement, error is 11 std, -12 std time: 55.806
# discarding measurement, error is 11 std, -12 std time: 56.044
# discarding measurement, error is 11 std, -12 std time: 56.282
# discarding measurement, error is 11 std, -12 std time: 56.398
# discarding measurement, error is 11 std, -12 std time: 56.764
# discarding measurement, error is 11 std, -12 std time: 57.002
# discarding measurement, error is 11 std, -12 std time: 57.166
# discarding measurement, error is 11 std, -12 std time: 57.524
# discarding measurement, error is 11 std, -12 std time: 57.642
# discarding measurement, error is 11 std, -12 std time: 58.008
# discarding measurement, error is 11 std, -12 std time: 58.248
# discarding measurement, error is 11 std, -12 std time: 58.484
# discarding measurement, error is 11 std, -12 std time: 58.78
# discarding measurement, error is 10 std, -12 std time: 59.02
# discarding measurement, error is 10 std, -12 std time: 59.256
# discarding measurement, error is 10 std, -13 std time: 59.494
# discarding measurement, error is 10 std, -13 std time: 59.822
# discarding measurement, error is 10 std, -13 std time: 60.056
# discarding measurement, error is 10 std, -13 std time: 60.298
# discarding measurement, error is 10 std, -12 std time: 60.538
# discarding measurement, error is 10 std, -12 std time: 60.77
# discarding measurement, error is 10 std, -12 std time: 60.884
# discarding measurement, error is 10 std, -12 std time: 61.326
# discarding measurement, error is 10 std, -12 std time: 61.566
# discarding measurement, error is 10 std, -12 std time: 61.676
# discarding measurement, error is 10 std, -12 std time: 62.112
# discarding measurement, error is 10 std, -12 std time: 62.35
# discarding measurement, error is 10 std, -12 std time: 62.588
# discarding measurement, error is 10 std, -12 std time: 62.82
# discarding measurement, error is 10 std, -12 std time: 63.064
# discarding measurement, error is 10 std, -12 std time: 63.358
# discarding measurement, error is 10 std, -12 std time: 63.596
# discarding measurement, error is 10 std, -12 std time: 63.834
# discarding measurement, error is 10 std, -12 std time: 64.072
# discarding measurement, error is 10 std, -12 std time: 64.304
# discarding measurement, error is 10 std, -12 std time: 64.54
# discarding measurement, error is 10 std, -12 std time: 64.818
# discarding measurement, error is 10 std, -12 std time: 65.056
# discarding measurement, error is 10 std, -12 std time: 65.344
# discarding measurement, error is 10 std, -12 std time: 65.462
# discarding measurement, error is 10 std, -12 std time: 65.822
# discarding measurement, error is 10 std, -12 std time: 66.066
# discarding measurement, error is 10 std, -12 std time: 66.18
# discarding measurement, error is 10 std, -12 std time: 66.544
# discarding measurement, error is 9 std, -12 std time: 66.78
# discarding measurement, error is 9 std, -12 std time: 67.016
# discarding measurement, error is 9 std, -12 std time: 67.314
# discarding measurement, error is 9 std, -12 std time: 67.552
# discarding measurement, error is 9 std, -12 std time: 67.786
# discarding measurement, error is 9 std, -12 std time: 68.024
# discarding measurement, error is 9 std, -12 std time: 68.26
# discarding measurement, error is 9 std, -12 std time: 68.552
# discarding measurement, error is 9 std, -12 std time: 68.786
# discarding measurement, error is 9 std, -12 std time: 69.028
# discarding measurement, error is 9 std, -12 std time: 69.26
# discarding measurement, error is 9 std, -12 std time: 69.5
# discarding measurement, error is 9 std, -12 std time: 69.774
# discarding measurement, error is 9 std, -12 std time: 69.932
# discarding measurement, error is 9 std, -12 std time: 70.304
# discarding measurement, error is 9 std, -12 std time: 70.534
# discarding measurement, error is 9 std, -12 std time: 70.65
# discarding measurement, error is 9 std, -12 std time: 71.016
# discarding measurement, error is 9 std, -12 std time: 71.304
# discarding measurement, error is 9 std, -12 std time: 71.548
# discarding measurement, error is 9 std, -12 std time: 71.778
# discarding measurement, error is 9 std, -12 std time: 72.012
# discarding measurement, error is 9 std, -12 std time: 72.258
# discarding measurement, error is 9 std, -12 std time: 72.544
# discarding measurement, error is 9 std, -12 std time: 72.778
# discarding measurement, error is 9 std, -12 std time: 73.018
# discarding measurement, error is 9 std, -12 std time: 73.256
# discarding measurement, error is 9 std, -12 std time: 73.542
# discarding measurement, error is 9 std, -12 std time: 73.786
# discarding measurement, error is 9 std, -12 std time: 74.022
# discarding measurement, error is 9 std, -12 std time: 74.256
# discarding measurement, error is 9 std, -12 std time: 74.364
# discarding measurement, error is 9 std, -12 std time: 74.764
# discarding measurement, error is 9 std, -12 std time: 75.096
# discarding measurement, error is 9 std, -12 std time: 75.534
# discarding measurement, error is 9 std, -12 std time: 75.766
# discarding measurement, error is 9 std, -12 std time: 76.002
# discarding measurement, error is 9 std, -12 std time: 76.298
# discarding measurement, error is 9 std, -12 std time: 76.532
# discarding measurement, error is 9 std, -12 std time: 76.766
# discarding measurement, error is 9 std, -12 std time: 77.004
# discarding measurement, error is 9 std, -12 std time: 77.298
# discarding measurement, error is 9 std, -12 std time: 77.534
# discarding measurement, error is 9 std, -12 std time: 77.772
# discarding measurement, error is 9 std, -12 std time: 78.01
# discarding measurement, error is 9 std, -12 std time: 78.308
# discarding measurement, error is 9 std, -12 std time: 78.542
# discarding measurement, error is 9 std, -12 std time: 78.78
# discarding measurement, error is 9 std, -12 std time: 78.896
# discarding measurement, error is 9 std, -12 std time: 79.266
# discarding measurement, error is 9 std, -12 std time: 79.502
# discarding measurement, error is 9 std, -12 std time: 79.662
# discarding measurement, error is 9 std, -12 std time: 80.09
# discarding measurement, error is 9 std, -12 std time: 80.332
# discarding measurement, error is 9 std, -12 std time: 80.568
# discarding measurement, error is 9 std, -12 std time: 80.81
# discarding measurement, error is 9 std, -12 std time: 81.102
# discarding measurement, error is 9 std, -12 std time: 81.346
# discarding measurement, error is 9 std, -12 std time: 81.578
# discarding measurement, error is 9 std, -12 std time: 81.814
# discarding measurement, error is 9 std, -12 std time: 82.056
# discarding measurement, error is 9 std, -12 std time: 82.354
# discarding measurement, error is 9 std, -12 std time: 82.586
# discarding measurement, error is 9 std, -12 std time: 82.822
# discarding measurement, error is 9 std, -11 std time: 83.064
# discarding measurement, error is 9 std, -11 std time: 83.4
# discarding measurement, error is 9 std, -11 std time: 83.834
# discarding measurement, error is 9 std, -11 std time: 84.11
# discarding measurement, error is 9 std, -11 std time: 84.476
# discarding measurement, error is 9 std, -11 std time: 84.75
# discarding measurement, error is 9 std, -11 std time: 85.046
# discarding measurement, error is 9 std, -11 std time: 85.282
# discarding measurement, error is 9 std, -11 std time: 85.522
# discarding measurement, error is 9 std, -11 std time: 85.756
# discarding measurement, error is 9 std, -11 std time: 86.054
# discarding measurement, error is 9 std, -11 std time: 86.296
# discarding measurement, error is 9 std, -11 std time: 86.526
# discarding measurement, error is 8 std, -11 std time: 86.766
# discarding measurement, error is 8 std, -11 std time: 87.006
# discarding measurement, error is 8 std, -11 std time: 87.3
# discarding measurement, error is 8 std, -11 std time: 87.536
# discarding measurement, error is 8 std, -11 std time: 87.862
# discarding measurement, error is 8 std, -11 std time: 88.23
# discarding measurement, error is 8 std, -11 std time: 88.518
# discarding measurement, error is 8 std, -11 std time: 88.634
# discarding measurement, error is 8 std, -11 std time: 89.002
# discarding measurement, error is 8 std, -11 std time: 89.234
# discarding measurement, error is 8 std, -11 std time: 89.47
# discarding measurement, error is 8 std, -11 std time: 89.802
# discarding measurement, error is 8 std, -11 std time: 90.03
# discarding measurement, error is 8 std, -11 std time: 90.266
# discarding measurement, error is 8 std, -11 std time: 90.502
# discarding measurement, error is 8 std, -11 std time: 90.738
# discarding measurement, error is 8 std, -11 std time: 91.032
# discarding measurement, error is 8 std, -11 std time: 91.268
# discarding measurement, error is 8 std, -11 std time: 91.504
# discarding measurement, error is 8 std, -11 std time: 91.742
# discarding measurement, error is 8 std, -11 std time: 92.036
# discarding measurement, error is 8 std, -11 std time: 92.27
# discarding measurement, error is 8 std, -11 std time: 92.388
# discarding measurement, error is 8 std, -11 std time: 92.746
# discarding measurement, error is 8 std, -11 std time: 93.042
# discarding measurement, error is 8 std, -11 std time: 93.158
# discarding measurement, error is 8 std, -11 std time: 93.52
# discarding measurement, error is 8 std, -11 std time: 93.754
# discarding measurement, error is 8 std, -11 std time: 93.994
# discarding measurement, error is 8 std, -11 std time: 94.23
# discarding measurement, error is 8 std, -11 std time: 94.464
# discarding measurement, error is 8 std, -11 std time: 94.79
# discarding measurement, error is 8 std, -11 std time: 95.022
# discarding measurement, error is 8 std, -11 std time: 95.264
# discarding measurement, error is 8 std, -11 std time: 95.498
# discarding measurement, error is 8 std, -11 std time: 95.792
# discarding measurement, error is 8 std, -11 std time: 96.024
# discarding measurement, error is 8 std, -11 std time: 96.26
# discarding measurement, error is 8 std, -11 std time: 96.49
# discarding measurement, error is 8 std, -11 std time: 96.788
# discarding measurement, error is 8 std, -11 std time: 96.896
# discarding measurement, error is 8 std, -11 std time: 97.264
# discarding measurement, error is 8 std, -11 std time: 97.498
# discarding measurement, error is 8 std, -11 std time: 97.616
# discarding measurement, error is 8 std, -11 std time: 98.05
# discarding measurement, error is 8 std, -11 std time: 98.282
# discarding measurement, error is 8 std, -11 std time: 98.516
# discarding measurement, error is 8 std, -11 std time: 98.75
# discarding measurement, error is 8 std, -11 std time: 98.99
# discarding measurement, error is 8 std, -11 std time: 99.206
# discarding measurement, error is 8 std, -11 std time: 99.488
# discarding measurement, error is 8 std, -11 std time: 99.746
# discarding measurement, error is 8 std, -10 std time: 99.96
# discarding measurement, error is 8 std, -10 std time: 100.184
# discarding measurement, error is 8 std, -10 std time: 100.462
# discarding measurement, error is 8 std, -10 std time: 100.686
# discarding measurement, error is 8 std, -10 std time: 100.91
# discarding measurement, error is 8 std, -10 std time: 101.232
# discarding measurement, error is 8 std, -10 std time: 101.652
# discarding measurement, error is 8 std, -10 std time: 101.876
# discarding measurement, error is 8 std, -10 std time: 101.99
# discarding measurement, error is 8 std, -10 std time: 102.33
# discarding measurement, error is 8 std, -10 std time: 102.606
# discarding measurement, error is 8 std, -10 std time: 102.832
# discarding measurement, error is 8 std, -10 std time: 103.054
# discarding measurement, error is 8 std, -10 std time: 103.272

# %%
ukfdf = neo6mdf.copy()
ukfdf['lat'] = latarr
ukfdf['lon'] = lonarr
ukfdf['speed'] = velarr
fig = px.line_mapbox(ukfdf, lat="lat", lon="lon",hover_data={"time","lat","lon","speed","cog"},text="time", zoom=3, height=600)     
fig.update_layout(mapbox_style="stamen-terrain", mapbox_zoom=17, mapbox_center_lat = ukfdf.lat[0],mapbox_center_lon=ukfdf.lon[0],
    margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
px.line(y = [neo6mdf.speed,ukfdf.speed],x=ukfdf.time)

# %%
px.line(x=neo6mdf.time,y=neo6mdf.cog)

# %%
latRef
# Out:
# 0.7282518948969492

# %%
vx,vy,vz = vel2ned(neo6mdf.speed[0],151,1)

# %%
x,y,z= lla2ned(neo6mdf.lat,neo6mdf.lon,20)

# %%
xn = x+100 + 0.441 * vx
yn = y+100 + 0.441 * vy

# %%
latn,lotn,altn = ned2lla(xn,yn,z)

# %%
neo6mdf.lat = latn
neo6mdf.lon = lotn
